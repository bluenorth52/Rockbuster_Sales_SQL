# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os 
# command to import appropriate libraries

# %%
df_opc = pd.read_pickle(r'C:\Users\boudl\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')
# command to import orders_products.csv as df_prods

# %%
df_prods = pd.read_csv(r'C:\Users\boudl\Instacart Basket Analysis\02 Data\Prepared Data\products_check.csv', index_col = False)
# command to import products.csv as df_prods

# %% [markdown]
# # Combine Data

# %%
df_prods.drop(columns = ['Unnamed: 0'])
# command to remove unnmamed: 0 column from dataframe
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods = df_prods.drop(columns = ['Unnamed: 0'])
# command to define database without this column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_prods = df_prods.drop(columns = ['Unnamed: 0'])
#
# NameError: name 'df_prods' is not defined

# %%
df_opc.shape
#study shape of dataframe
# Out:
# (32640698, 11)

# %%
df_prods.shape
# study shape of dataframe
# Out:
# (49693, 5)

# %%
df_opc.head()
# study first five rows of dataframe
# Out:
#    order_id  user_id  order_number  day_of_week  order_hour_of_day  \
# 0   2539329        1             1            2                  8
# 1   2539329        1             1            2                  8
# 2   2539329        1             1            2                  8
# 3   2539329        1             1            2                  8
# 4   2539329        1             1            2                  8
#
#    days_since_prior_order  first_order_flag  product_id  add_to_cart_order  \
# 0                     NaN              True       196.0                1.0
# 1                     NaN              True     14084.0                2.0
# 2                     NaN              True     12427.0                3.0
# 3                     NaN              True     26088.0                4.0
# 4                     NaN              True     26405.0                5.0
#
#    reordered _merge
# 0        0.0   both
# 1        0.0   both
# 2        0.0   both
# 3        0.0   both
# ...

# %%
df_prods.head()
# study first first rows of dataframe
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_orders_products_check = df_opc.merge(df_prods, on = 'product_id' , indicator = True)
# command to merge dataframes with CF command in teaching
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_orders_products_check = df_opc.merge(df_prods, on = 'product_id' , indicator = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10490, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10471 @Substitution("")
#   10472 @Appender(_merge_doc, indents=2)
#   10473 def merge(
#    (...)
#   10486     validate: MergeValidate | None = None,
#   10487 ) -> DataFrame:
#   10488     from pandas.core.reshape.merge import merge
# > 10490     return merge(
#   10491         self,
#   10492         right,
#   10493         how=how,
#   10494         on=on,
#   10495         left_on=left_on,
#   10496         right_on=right_on,
#   10497         left_index=left_index,
#   10498         right_index=right_index,
# ...

# %%
df_orders_products_check = df_opc.merge(df_prods, on = 'product_id', indicator = 'merge_indicator')
# new command to merge dataframes, since df_opc is already a merged dataframe

# %%
df_orders_products_check['_merge'].value_counts() 
# command to determine match type
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_orders_products_check.shape
#command to see dataframe shape
# Out:
# (32434212, 16)

# %%
df_orders_products_check.drop(columns = ['_merge'])
# Out:
#           order_id  user_id  order_number  day_of_week  order_hour_of_day  \
# 0          2539329        1             1            2                  8
# 1          2398795        1             2            3                  7
# 2           473747        1             3            3                 12
# 3          2254736        1             4            4                  7
# 4           431534        1             5            4                 15
# ...            ...      ...           ...          ...                ...
# 32434207   1320836   202557            17            2                 15
# 32434208     31526   202557            18            5                 11
# 32434209    758936   203436             1            2                  7
# 32434210   2745165   203436             2            3                  5
# 32434211   3093936   205420             1            4                 14
#
#           days_since_prior_order  first_order_flag  product_id  \
# ...

# %%
df_orders_products_check = df_orders_products_check.drop(columns = ['_merge'])

# %%
df_orders_products_check.drop(columns = ['_merge_indicator'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_orders_products_check.drop(columns = ['_merge_indicator'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
# ...

# %%
df_orders_products_check = df_orders_products_check.drop(columns = ['merge_indicator'])

# %%
df_orders_products_check.head()
# command to see first five rows of dataframe
# Out:
#    order_id  user_id  order_number  day_of_week  order_hour_of_day  \
# 0   2539329        1             1            2                  8
# 1   2398795        1             2            3                  7
# 2    473747        1             3            3                 12
# 3   2254736        1             4            4                  7
# 4    431534        1             5            4                 15
#
#    days_since_prior_order  first_order_flag  product_id  add_to_cart_order  \
# 0                     NaN              True       196.0                1.0
# 1                    15.0             False       196.0                1.0
# 2                    21.0             False       196.0                1.0
# 3                    29.0             False       196.0                1.0
# 4                    28.0             False       196.0                1.0
#
#    reordered product_name  aisle_id  department_id  prices
# ...

# %%
df_orders_products_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434212 entries, 0 to 32434211
# Data columns (total 14 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   day_of_week             int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   first_order_flag        bool
#  7   product_id              float64
#  8   add_to_cart_order       float64
#  9   reordered               float64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
# dtypes: bool(1), float64(5), int64(7), object(1)
# memory usage: 3.2+ GB

# %% [markdown]
# # Export Data

# %%
path = r'C:\Users\boudl\Instacart Basket Analysis'
# define path export

# %%
df_opc.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_final.pkl'))
# command to export file
