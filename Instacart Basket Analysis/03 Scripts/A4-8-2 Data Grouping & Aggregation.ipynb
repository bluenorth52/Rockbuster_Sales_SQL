# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.read_csv(r'C:\Users\boudl\Instacart Basket Analysis\02 Data\Prepared Data\OPCC\opc_chunk1.csv')
#load dataframe chunk one

# %%
df2 = pd.read_csv(r'C:\Users\boudl\Instacart Basket Analysis\02 Data\Prepared Data\OPCC\opc_chunk2.csv')
#load dataframe chunk two

# %%
df3 = pd.read_csv(r'C:\Users\boudl\Instacart Basket Analysis\02 Data\Prepared Data\OPCC\opc_chunk3.csv')
#load dataframe chunk three

# %%
df4 = pd.read_csv(r'C:\Users\boudl\Instacart Basket Analysis\02 Data\Prepared Data\OPCC\opc_chunk4.csv')
#load dataframe chunk four

# %%
df_opc = pd.concat([df1, df2, df3, df4], ignore_index=True)
#combine all four chunked dataframes to one for study

# %% [markdown]
# # Assignment Questions

# %%
df_opc.head(2)
#display first two rows of dataframe
# Out:
#    Unnamed: 0  order_id  user_id  order_number  day_of_week  \
# 0           0   2539329        1             1            2
# 1           1   2398795        1             2            3
#
#    order_hour_of_day  days_since_prior_order  first_order_flag  product_id  \
# 0                  8                     NaN              True       196.0
# 1                  7                    15.0             False       196.0
#
#    add_to_cart_order  ...  product_name aisle_id  department_id  prices  \
# 0                1.0  ...          Soda       77              7     9.0
# 1                1.0  ...          Soda       77              7     9.0
#
#    max_order  loyalty_flag avg_price_per_user  spending_flag  \
# 0         10  New customer           6.367797    Low spender
# 1         10  New customer           6.367797    Low spender
#
#           user_frequency median_days_since_prior
# 0  Non-frequent customer                    20.5
# ...

# %%
df_opc.drop(columns = ['Unnamed: 0'])
#drop misc column
# Out:
#           order_id  user_id  order_number  day_of_week  order_hour_of_day  \
# 0          2539329        1             1            2                  8
# 1          2398795        1             2            3                  7
# 2           473747        1             3            3                 12
# 3          2254736        1             4            4                  7
# 4           431534        1             5            4                 15
# ...            ...      ...           ...          ...                ...
# 32434207    694731   202557            16            1                 14
# 32434208   1320836   202557            17            2                 15
# 32434209     31526   202557            18            5                 11
# 32434210    758936   203436             1            2                  7
# 32434211   2745165   203436             2            3                  5
#
#           days_since_prior_order  first_order_flag  product_id  \
# ...

# %%
df_opc = df_opc.drop(columns = ['Unnamed: 0'])
#define dataframe without this column

# %%
df_opc.shape
#command to study shape of dataframe
# Out:
# (32434212, 20)

# %%
df_opc['loyalty_flag'].value_counts(dropna = False)
#command to display new flag column values
# Out:
# loyalty_flag
# Regular customer    15832287
# Loyal customer      10246255
# New customer         6355670
# Name: count, dtype: int64

# %%
spending_loyalty = df_opc.groupby('loyalty_flag')['prices'].agg(['mean', 'median', 'std'])
#command to study spending habits of customers

# %%
spending_loyalty.head()
#command to study mean median and standard deviation of customer spending habits
# Out:
#                        mean  median         std
# loyalty_flag
# Loyal customer    10.393847     7.4  328.458082
# New customer      13.223022     7.4  592.552504
# Regular customer  12.509866     7.4  540.426757

# %%
df_opc['spending_flag'].value_counts(dropna = False)
#command to study counts of new flag column
# Out:
# spending_flag
# Low spender     30832319
# High spender     1601893
# Name: count, dtype: int64

# %%
df_opc['user_frequency'].value_counts(dropna=False)
#command to display new flag column counts
# Out:
# user_frequency
# Frequent customer        21525096
# Regular customer          7174586
# Non-frequent customer     3722035
# NaN                         12495
# Name: count, dtype: int64

# %% [markdown]
# # Export Dataframe

# %%
path = r'C:\Users\boudl\Instacart Basket Analysis'
# define path export

# %%
df_opc.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'opc_combined_chunk.pkl'))
#command to export dataframe
